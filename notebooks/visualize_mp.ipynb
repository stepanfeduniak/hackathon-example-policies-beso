# %%
from IPython.display import Video
import os
video_dir = "lerobot_data/rail_insertion_dataset__lerobot/videos/chunk-000/observation.images.rgb_static/episode_000027.mp4"
assert os.path.exists(video_dir), f"File does not exist: {video_dir}"
Video(video_dir, embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
4,5,6,10,12,14,15,16,17,18,19,20,23,26,28,29,36,38,42,43,45,46,47,52
